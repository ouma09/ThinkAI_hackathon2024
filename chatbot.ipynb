# %%
from twilio.rest import Client

# Remplacez les valeurs suivantes par vos identifiants Twilio
account_sid = 'AC744de398df12c76b1e20942b18b4a945'
auth_token = '28ef95a2739eae32f824d46aa2de4d66'

client = Client(account_sid, auth_token)

# Fonction pour envoyer le message de bienvenue
def send_welcome_message():
    message = client.messages.create(
        from_='whatsapp:+14155238886',
        body='Bonjour et bienvenue ! Êtes-vous prêt à démarrer ? Répondez "start" pour commencer.',
        to='whatsapp:+212669749456'
    )
    print(message.sid)


# Fonction pour vérifier si la réponse de l'utilisateur est "start"
def is_start(response):
    return response.strip().lower() == "start"

# Variable pour garder une trace si le message de bienvenue a déjà été envoyé
welcome_sent = False

# Boucle pour attendre la réponse de l'utilisateur
while True:
    # Si le message de bienvenue n'a pas été envoyé, envoyez-le
    if not welcome_sent:
        send_welcome_message()
        welcome_sent = True
    
    # Récupérer la réponse de l'utilisateur
    incoming_message = client.messages.list()[0]  # Récupérer le dernier message reçu
    
    # Vérifier si la réponse est "start"
    if is_start(incoming_message.body):
        response_message = "D'accord, que puis-je faire pour vous maintenant ?"
        client.messages.create(
            from_='whatsapp:+14155238886',
            body=response_message,
            to='whatsapp:+212669749456'
        )
        print("Message envoyé à l'utilisateur :", response_message)
        break
# Out:
# SM30129078b737d123af1e36e9bf4ebcd4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [94], in <cell line: 34>()
#      36     welcome_sent = True
#      38 # Récupérer la réponse de l'utilisateur
# ---> 39 incoming_message = client.messages.list()[0]  # Récupérer le dernier message reçu
#      41 # Vérifier si la réponse est "start"
#      42 if incoming_message.body.strip().lower() == "start":
#
# File ~\anaconda3\lib\site-packages\twilio\rest\api\v2010\account\message\__init__.py:785, in MessageList.list(self, to, from_, date_sent, date_sent_before, date_sent_after, limit, page_size)
#     756 def list(
#     757     self,
#     758     to: Union[str, object] = values.unset,
#    (...)
#     764     page_size: Optional[int] = None,
#     765 ) -> List[MessageInstance]:
#     766     """
#     767     Lists MessageInstance records from the API as a list.
# ...

# %%
# !pip install pyTelegramBotAPI
# Out:
# ...
# WARNING: Ignoring invalid distribution -ycryptodome (c:\users\hanane\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ycryptodome (c:\users\hanane\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import os
import telebot

BOT_TOKEN = '6994858464:AAEh2oiajC33UvtNLUNxpR0rOHryx81I7zo'

bot = telebot.TeleBot(BOT_TOKEN)

waiting_for_image = {}

@bot.message_handler(commands=['start', 'hello'])
def send_welcome(message):
    chat_id = message.chat.id
    if chat_id not in waiting_for_image:
        waiting_for_image[chat_id] = True
        bot.reply_to(message, "Please send an image.")
    else:
        bot.reply_to(message, "I'm still waiting for an image. Please send one.")

@bot.message_handler(content_types=['text'])
def handle_text(message):
    chat_id = message.chat.id
    if chat_id in waiting_for_image:
        bot.reply_to(message, "I'm still waiting for an image. Please send one.")
    else:
        bot.reply_to(message, "I'm not sure what you mean. Please send an image.")

@bot.message_handler(content_types=['photo'])
def handle_photo(message):
    chat_id = message.chat.id
    if chat_id in waiting_for_image:
        del waiting_for_image[chat_id]
        bot.reply_to(message, "Thanks for the photo!")
    else:
        bot.reply_to(message, "Thanks for the photo! If you have any more, feel free to send them.")

bot.infinity_polling()
# Out:
# 2024-05-19 03:17:59,652 (__init__.py:966 MainThread) ERROR - TeleBot: "Infinity polling: polling exited"
# 2024-05-19 03:17:59,652 (__init__.py:968 MainThread) ERROR - TeleBot: "Break infinity polling"

# %%
from openai import OpenAI
import base64
import json
import os
from urllib.parse import urlparse

os.environ['OPENAI_API_KEY'] = "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"
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')


image_local = 'R.jpg'
image_url = f"data:image/jpeg;base64,{encode_image(image_local)}"
#image_url = 'https://d2908q01vomqb2.cloudfront.net/f1f836cb4ea6efb2a0b1b99f41ad8b103eff4b59/2021/02/19/ML-1955-2.jpg'

client = OpenAI() #Best practice needs OPENAI_API_KEY environment variable
# client = OpenAI('OpenAI API Key here')

response = client.chat.completions.create(
    model='gpt-4-vision-preview', 
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Return JSON document with data. Only return JSON not other text"},
                {
                    "type": "image_url",
                    "image_url": {"url": image_url}
                }
            ],
        }
    ],
    max_tokens=1000,
)

print(response.choices[0].message.content)
# Out:
# ```json
# {
#   "GB": {
#     "value": 10.44,
#     "unit": "10^3/µl",
#     "reference_range": "(5.2/13.9)"
#   },
#   "Lymph": {
#     "value": 3.40,
#     "unit": "10^3/µl",
#     "reference_range": "(1.2/3.2)"
#   },
#   "%Lymph": {
#     "value": 33.30,
#     "unit": "%",
#     "reference_range": "(16.0/32.0)"
#   },
#   "Mono": {
#     "value": 0.3,
#     "unit": "10^3/µl",
#     "reference_range": "(0.3/0.8)"
#   },
#   "%Mono": {
#     "value": 3.4,
#     "unit": "%",
#     "reference_range": "(0.5/0.5)"
#   },
#   "Gran": {
#     "value": 6.7,
#     "unit": "10^3/µl",
#     "reference_range": "(1.2/6.8)"
#   },
#   "%Gran": {
#     "value": 63.3,
#     "unit": "%",
#     "reference_range": "(40.0/79.0)"
#   },
#   "Eos": {
#     "value": 4.5,
#     "unit": "%",
#     "reference_range": "(1.4/10.0)"
#   },
#   "GR": {
#     "value": 10.64,
#     "unit": "10^6/µl",
#     "reference_range": "(6.40/10.00)"
#   },
#   "Hb": {
#     "value": 11.25,
#     "unit": "g/dl",
# ...

# %%
from openai import OpenAI

# %%
# Encode l'image pour l'utiliser dans la requête
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

image_local = 'R.jpg'
image_url = f"data:image/jpeg;base64,{encode_image(image_local)}"

# Exécute la requête auprès d'OpenAI
client = OpenAI() #Best practice needs OPENAI_API_KEY environment variable
response = client.chat.completions.create(
    model='gpt-4-vision-preview', 
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Return JSON document with data. Only return JSON not other text"},
                {
                    "type": "image_url",
                    "image_url": {"url": image_url}
                }
            ],
        }
    ],
    max_tokens=1000,
)

# Utilise la réponse pour créer la requête pour la chaîne de questions-réponses
json_info = response.choices[0].message.content
# Out:
# '```json\n{\n  "GB": {\n    "value": 10.44,\n    "unit": "10^3/µl",\n    "reference_range": "(5.2/13.9)"\n  },\n  "Lymph": {\n    "value": 3.40,\n    "unit": "10^3/µl",\n    "reference_range": "(1.2/3.2)"\n  },\n  "%Lymph": {\n    "value": 33.30,\n    "unit": "%",\n    "reference_range": "(16.0/32.0)"\n  },\n  "Mono": {\n    "value": 0.3,\n    "unit": "10^3/µl",\n    "reference_range": "(.3/.8)"\n  },\n  "%Mono": {\n    "value": 3.4,\n    "unit": "%",\n    "reference_range": "(.5/8.0)"\n  },\n  "Gran": {\n    "value": 6.7,\n    "unit": "10^3/µl",\n    "reference_range": "(1.2/6.8)"\n  },\n  "%Gran": {\n    "value": 63.3,\n    "unit": "%",\n    "reference_range": "(40.0/79.0)"\n  },\n  "Eos": {\n    "value": 4.5,\n    "unit": "%",\n    "reference_range": ""\n  },\n  "GR": {\n    "value": 10.64,\n    "unit": "10^6/µl",\n    "reference_range": "(6.40/10.00)"\n  },\n  "Hb": {\n    "value": 11.25,\n    "unit": "g/dl",\n    "reference_range": "(11.0/17.0)"\n  },\n  "HCT": {\n    "value": 3
# ...

# %%
print(json_info)
# Out:
# ```json
# {
#   "GB": {
#     "value": 10.44,
#     "unit": "10^3/µl",
#     "reference_range": "(5.2/13.9)"
#   },
#   "Lymph": {
#     "value": 3.40,
#     "unit": "10^3/µl",
#     "reference_range": "(1.2/3.2)"
#   },
#   "%Lymph": {
#     "value": 33.30,
#     "unit": "%",
#     "reference_range": "(16.0/32.0)"
#   },
#   "Mono": {
#     "value": 0.3,
#     "unit": "10^3/µl",
#     "reference_range": "(.3/.8)"
#   },
#   "%Mono": {
#     "value": 3.4,
#     "unit": "%",
#     "reference_range": "(.5/8.0)"
#   },
#   "Gran": {
#     "value": 6.7,
#     "unit": "10^3/µl",
#     "reference_range": "(1.2/6.8)"
#   },
#   "%Gran": {
#     "value": 63.3,
#     "unit": "%",
#     "reference_range": "(40.0/79.0)"
#   },
#   "Eos": {
#     "value": 4.5,
#     "unit": "%",
#     "reference_range": ""
#   },
#   "GR": {
#     "value": 10.64,
#     "unit": "10^6/µl",
#     "reference_range": "(6.40/10.00)"
#   },
#   "Hb": {
#     "value": 11.25,
#     "unit": "g/dl",
# ...

# %%
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.retrievers import ParentDocumentRetriever
from langchain.chains import RetrievalQA
from openai import OpenAI
import base64
import os

# Configuration de l'API OpenAI
os.environ['OPENAI_API_KEY'] = "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"

# Chargement des documents PDF à partir d'un répertoire
loader = DirectoryLoader('CBC_Documents', glob='*.pdf')
documents = loader.load()
# Chargement des documents PDF à partir d'un répertoire


# Traitement des documents textuels
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts = text_splitter.split_documents(documents)

# Initialisation des embeddings OpenAI
embedding = OpenAIEmbeddings()
db = Chroma(embedding_function=embedding)

# Configuration du système de récupération
retriever = ParentDocumentRetriever(vector_store=db)

# Initialisation de l'instance OpenAI
openai_instance = OpenAI(api_key=openai_api_key)

# Création de la chaîne de questions-réponses
qa_chain = RetrievalQA(llm=openai_instance, retriever=retriever)

# Encode l'image pour l'utiliser dans la requête
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

image_local = 'R.jpg'
image_url = f"data:image/jpeg;base64,{encode_image(image_local)}"

# Exécute la requête auprès d'OpenAI
response = openai_instance.chat.completions.create(
    model='gpt-4-vision-preview', 
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Return JSON document with data. Only return JSON not other text"},
                {
                    "type": "image_url",
                    "image_url": {"url": image_url}
                }
            ],
        }
    ],
    max_tokens=1000,
)

# Utilise la réponse pour créer la requête pour la chaîne de questions-réponses
json_info = response.choices[0].message.content
query = f"Je souhaite obtenir des informations sur les valeurs pour l'analyse de NFS suivantes : {json_info}. Pourriez-vous fournir plus de détails à ce sujet ?"

# Utilisation de la requête dans la chaîne de questions-réponses
llm_response = qa_chain(query)

# Affichage du contenu de la première page de la réponse
print(llm_response[0].page_content)
# Out:
# The MIME type of 'CBC_Documents\\Hémogramme.pdf' is "cannot open `CBC_Documents\\Hémogramme.pdf' (No such file or directory)". This file type is not currently supported in unstructured.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [23], in <cell line: 29>()
#      26 db = Chroma(embedding_function=embedding)
#      28 # Configuration du système de récupération
# ---> 29 retriever = ParentDocumentRetriever(vector_store=db)
#      31 # Initialisation de l'instance OpenAI
#      32 openai_instance = OpenAI(api_key=openai_api_key)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pydantic\v1\main.py:339, in BaseModel.__init__(__pydantic_self__, **data)
#     333 """
#     334 Create a new model by parsing and validating input data from keyword arguments.
#     335
#     336 Raises ValidationError if the input data cannot be parsed to form a valid model.
# ...

# %%
# Out:
# The MIME type of 'CBC_Documents\\Hémogramme.pdf' is "cannot open `CBC_Documents\\Hémogramme.pdf' (No such file or directory)". This file type is not currently supported in unstructured.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 6>()
#       2 documents = loader.load()
#       4 embeddings = OpenAIEmbeddings()
# ----> 6 db = Chroma.from_documents(documents=documents, embedding=embeddings, persist_directory='db')
#       7 db.persist()
#       8 retriever.add_documents(documents, ids=None)
#
# File ~\anaconda3\lib\site-packages\langchain_community\vectorstores\chroma.py:790, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     788 texts = [doc.page_content for doc in documents]
#     789 metadatas = [doc.metadata for doc in documents]
# ...
